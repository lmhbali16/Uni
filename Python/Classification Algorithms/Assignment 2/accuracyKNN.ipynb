# %%
# this generates accuracy for knn with pima-folds and pima-folds with feature selection

# %%
foldsFile = open('C:/Users/zacda_sflvbog/OneDrive/3Y1S/Comp3308/assignment2/pima-cfs-cv.csv','r') # change file for regular pima-folds or folds with feature selection


rowfolds = foldsFile.read().strip('\n').split('\n')
dfFold = []

for i in range(len(rowfolds)):

    row = rowfolds[i].split(',')

    dfFold.append(row)
    
dfFold = np.array(dfFold)



fold_list = [[],[],[],[],[],[],[],[],[],[]]
i = 0
not_good = ['ï»¿fold1','','fold1','fold2','fold3','fold4','fold5','fold6','fold7','fold8','fold9','fold10']
for row in dfFold:
    
    if row[0] in not_good:
        i+= 0.5
    else:
        fold_list[int(i)].append(row)

fold_list[0][0]

for i in range(0,len(fold_list)):        
    fold_list[i] = np.array(fold_list[i])
    
fold_list = np.array(fold_list)

dfFold
# Out:
# array([['ï»¿fold1', '', '', '', '', ''],
#        ['0.264516', '0.169471', '0.171779', '0.116567', '0.166667', 'no'],
#        ['0.290323', '0.096154', '0.202454', '0.038002', '0', 'no'],
#        ...,
#        ['0.812903', '0.169471', '0.527607', '0.13877', '0.366667', 'yes'],
#        ['0.529032', '0.169471', '0.243354', '0.115713', '0.433333',
#         'yes'],
#        ['0.8', '0.169471', '0.343558', '0.353117', '0.516667', 'yes']],
#       dtype='<U8')

# %%
import numpy as np

def euclid_dist(data,inputs):

    return np.sqrt((np.sum(np.square(inputs - data),1)))

def knn(k,trainingset, testset):

    trainingvals = np.array(np.delete(trainingset,-1,1),dtype = float)
    testvals = np.array(np.delete(testset,-1,1),dtype = float)
    preds = []
    actual_preds = testset[:,-1]
    for val in testvals:
        #print(val)
        distances = euclid_dist(trainingvals,val)
        #print()
        distances = distances.reshape(1,distances.shape[0]).transpose()
        #print(distances[0:3])
        neighbours = []
        for i in range(distances.shape[0]):
            neighbours.append({'distance':distances[i][0],'class':trainingset[i][-1]})

        neighbours = sorted(neighbours, key = lambda i: i['distance'])

        k_points = neighbours[0:k]
        #print(k_points)
        count_yes = 0
        count_no = 0
        
        for row in k_points:
            if row['class'] == 'yes':
                count_yes += 1
            if row['class'] == 'no':
                count_no += 1
        if count_yes > count_no:
            preds.append('yes')
        if count_yes < count_no:
            preds.append('no')
        if count_yes == count_no:
            preds.append('yes')
    
    return (sum(preds == actual_preds)/len(actual_preds))
#knn(1,dfTrain,dfTest)

# %%
trainingfold = []
#print(len(fold_list))
fold_acc1 = []
fold_acc5 = []
to_die = fold_list
for i in range(0,len(fold_list)):
    testfold = to_die[i]
    trainingfold = np.concatenate(np.delete(to_die,i))
    
    fold_acc1.append(knn(1,trainingfold,testfold))
    fold_acc5.append(knn(5,trainingfold,testfold))
    
    to_die = fold_list
trainingfold
# Out:
# array([['0.264516', '0.169471', '0.171779', '0.116567', '0.166667', 'no'],
#        ['0.290323', '0.096154', '0.202454', '0.038002', '0', 'no'],
#        ['0.464516', '0.169471', '0.151329', '0.052519', '0.15', 'no'],
#        ...,
#        ['0.632258', '0.560096', '0.249489', '0.021349', '0.366667',
#         'yes'],
#        ['0.806452', '0.133413', '0.239264', '0.081127', '0.166667',
#         'yes'],
#        ['0.522581', '0.169471', '0.192229', '0.207942', '0.466667',
#         'yes']], dtype='<U8')

# %%
avg_acc1 = sum(fold_acc1)/len(fold_acc1)
avg_acc5 = sum(fold_acc5)/len(fold_acc5)
avg_acc1,avg_acc5
# Out:
# (0.682347915242652, 0.7512816131237183)

# %%
avg_acc1 = sum(fold_acc1)/len(fold_acc1)
avg_acc5 = sum(fold_acc5)/len(fold_acc5)
avg_acc1,avg_acc5
# Out:
# (0.6835269993164729, 0.7539131920710869)

# %%
# NB stuff now 
to_die[0]
# Out:
# array([['0.264516', '0.169471', '0.171779', '0.116567', '0.166667', 'no'],
#        ['0.290323', '0.096154', '0.202454', '0.038002', '0', 'no'],
#        ['0.464516', '0.169471', '0.151329', '0.052519', '0.15', 'no'],
#        ['0.458065', '0.169471', '0.349693', '0.023911', '0.133333', 'no'],
#        ['0.425806', '0.169471', '0.396728', '0.048249', '0.15', 'no'],
#        ['0.612903', '0.169471', '0.182004', '0.581981', '0.6', 'no'],
#        ['0.380645', '0.082933', '0.513292', '0.044833', '0.2', 'no'],
#        ['0.529032', '0.265625', '0.431493', '0.267293', '0.1', 'no'],
#        ['0.354839', '0.169471', '0.351738', '0.132365', '0.483333', 'no'],
#        ['0.341935', '0.151442', '0.102249', '0.174637', '0.016667', 'no'],
#        ['0.651613', '0.115385', '0.0818', '0.071307', '0.6', 'no'],
#        ['0.470968', '0.169471', '0.325153', '0.110589', '0.283333', 'no'],
#        ['0.419355', '0.169471', '0.364008', '0.199829', '0.65', 'no'],
#        ['0.283871', '0.048077', '0.134969', '0.0807', '0.016667', 'no'],
#        ['0.309677', '0.169471', '0.034765', '0.046968', '0.116667', 'no'],
#        ['0.503226', '0.169471', '0.192229', '0.185312', '0.4', 'no'],
#        ['0.380645', '0.213942', '0.118609', '0.379163', '0.2', 'no'],
#        ['0.606452', '0.169471', '0.306748', '0.146029', '0.233333', 'no'],
#        ['0.877419', '0.067308', '0.323108', '0.082408', '0.083333', 'no'],
#        ['0.574194', '0.169471', '0.449898', '0.263877', '0.266667', 'no'],
#        ['0.4', '0.169471', '0.092025', '0.067037', '0.45', 'no'],
#        ['0.741935', '0.169471', '0.188139', '0.092229', '0.316667', 'no'],
#        ['0.658065', '0.169471', '0.235174', '0.207515', '0.133333', 'no'],
#        ['0.174194', '0.169471', '0.200409', '0.216909', '0.016667', 'no'],
#        ['0.393548', '0.169471', '0.291564', '0.096926', '0.05', 'no'],
#        ['0.380645', '0.081731', '0.02454', '0.176345', '0.016667', 'no'],
#        ['0.367742', '0.026442', '0.122699', '0.191289', '0.083333', 'no'],
#        ['0.283871', '0.010817', '0.126789', '0.112724', '0.15', 'no'],
#        ['0.683871', '0.394231', '0.337423', '0.273271', '0.35', 'no'],
#        ['0.187097', '0.169471', '0.09816', '0.072588', '0', 'no'],
#        ['0.36129', '0.115385', '0.584867', '0.377455', '0.166667', 'no'],
#        ['0.658065', '0.169471', '0.456033', '0.727156', '0.383333', 'no'],
#        ['0.393548', '0.153846', '0.476483', '0.040564', '0.016667', 'no'],
#        ['0.258065', '0.169471', '0.291564', '0.096499', '0', 'no'],
#        ['0', '0.169471', '0.139059', '0.217336', '0.25', 'no'],
#        ['0.625806', '0.137019', '0.147239', '0.265158', '0.05', 'no'],
#        ['0.354839', '0.169471', '0.220859', '0.053373', '0.183333', 'no'],
#        ['0.419355', '0.169471', '0.501022', '0.327498', '0.55', 'no'],
#        ['0.329032', '0.028846', '0.02863', '0.109308', '0.066667', 'no'],
#        ['0.658065', '0.103365', '0.218814', '0.047395', '0.1', 'no'],
#        ['0.612903', '0.151442', '0.212679', '0.142186', '0.083333', 'no'],
#        ['0.548387', '0.307692', '0.345603', '0.065329', '0.033333', 'no'],
#        ['0.225806', '0.169471', '0.282209', '0.135781', '0.016667', 'no'],
#        ['0.496774', '0.169471', '0.132924', '0.026473', '0.016667', 'no'],
#        ['0.116129', '0.169471', '0.294479', '0.133646', '0.333333', 'no'],
#        ['0.329032', '0.169471', '0.398773', '0.12468', '0.1', 'no'],
#        ['0.43871', '0.169471', '0.139059', '0.09778', '0.05', 'no'],
#        ['0.445161', '0.169471', '0.08589', '0.026473', '0.016667', 'no'],
#        ['0.193548', '0.169471', '0.291564', '0.010248', '0.016667', 'no'],
#        ['0.251613', '0.06851', '0.226994', '0.294193', '0.25', 'no'],
#        ['0.670968', '0.169471', '0.314928', '0.234415', '0.483333',
#         'yes'],
#        ['0.896774', '0.169471', '0.104294', '0.253629', '0.183333',
#         'yes'],
#        ['0.6', '0.185096', '0.509202', '0.943638', '0.2', 'yes'],
#        ['0.219355', '0.088942', '0.261759', '0.072588', '0.083333',
#         'yes'],
#        ['0.987097', '0.635817', '0.251534', '0.034159', '0.533333',
#         'yes'],
#        ['0.522581', '0.169471', '0.291564', '0.065756', '0.55', 'yes'],
#        ['0.8', '0.169471', '0.404908', '0.195986', '0.216667', 'yes'],
#        ['0.935484', '1', '0.243354', '0.136635', '0.633333', 'yes'],
#        ['0.787097', '0.19351', '0.155419', '0.217336', '0.5', 'yes'],
#        ['0.36129', '0.169471', '0.241309', '0.173356', '0.183333', 'yes'],
#        ['0.477419', '0.259615', '0.564417', '0.201964', '0.166667',
#         'yes'],
#        ['0.406452', '0.169471', '0.233129', '0.075149', '0.166667',
#         'yes'],
#        ['0.458065', '0.098558', '0.335378', '0.19257', '0.183333', 'yes'],
#        ['0.980645', '0.169471', '0.441718', '0.159266', '0.333333',
#         'yes'],
#        ['0.483871', '0.169471', '0.220859', '0.078992', '0.133333',
#         'yes'],
#        ['0.63871', '0.158654', '0.376278', '0.075149', '0.5', 'yes'],
#        ['0.522581', '0.121394', '0.263804', '0.054227', '0.333333',
#         'yes'],
#        ['0.664516', '0.169471', '0.433538', '0.07643', '0.366667', 'yes'],
#        ['0.735484', '0.277644', '0.274029', '0.33006', '0.116667', 'yes'],
#        ['0.374194', '0.169471', '0.300613', '0.25064', '0.416667', 'yes'],
#        ['0.296774', '0.169471', '0.408998', '0.181469', '0.1', 'yes'],
#        ['0.432258', '0.231971', '0.386503', '0.560205', '0.583333',
#         'yes'],
#        ['0.819355', '0.271635', '0.556237', '0.274552', '0.55', 'yes'],
#        ['0.877419', '0.169471', '0.486708', '0.774979', '0.066667',
#         'yes'],
#        ['0.380645', '0.169471', '0.427403', '0.113578', '0.166667',
#         'yes'],
#        ['0.851613', '0.34375', '0.316973', '0.166097', '0.616667', 'yes'],
#        ['0.922581', '0.348558', '0.398773', '0.075149', '0.333333',
#         'yes']], dtype='<U8')
